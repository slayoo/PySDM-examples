# %%
import sys
from matplotlib import pylab
import numpy as np
from PySDM import Formulae
from PySDM.physics import si
from PySDM.physics import constants_defaults as const
from atmos_cloud_sim_uj_utils import show_plot
from PySDM_examples.Singer_Ward.aerosol import AerosolAlphaPineneDark

import warnings
from numba.core.errors import NumbaExperimentalFeatureWarning

# %%
ds = np.loadtxt("data/apinene_dark.csv",skiprows=1,delimiter=",")
r_dry = ds[:,0]/2*1e-9
ovf = np.minimum(ds[:,1], 0.99)
d_ovf = ds[:,2]
kappa_eff = ds[:,3]
d_kappa_eff = ds[:,4]
T = 300 * si.K

datay = kappa_eff
errory = d_kappa_eff

# pylab.figure(figsize=(8,6))
# pylab.rcParams.update({'font.size':20})
# pylab.errorbar(ovf, kappa_eff, yerr=d_kappa_eff, xerr=d_ovf, fmt='ko')
# pylab.xlabel("OVF")
# pylab.ylabel("$\kappa_{eff}$")
# pylab.rcParams.update({'font.size':20})
# pylab.grid()
# pylab.show()

# %%
from importlib import reload
import kappa_mcmc
reload(kappa_mcmc)
from kappa_mcmc import param_transform, get_model, MCMC

c = AerosolAlphaPineneDark(ovf)

# Ovad
model = "CompressedFilmOvadnevaite"
params = [-0.5, 0.5]
stepsize = [0.1, 0.1]

# # SL
# model = "SzyszkowskiLangmuir"
# params = [20, -12.0, 3.9]
# stepsize = [0.5, 0.1, 0.05]

# # Ruehl
# model = "CompressedFilmRuehl"
# params = [16.1, -12.0, 3.5, 1.5]
# stepsize = [0.1, 0.05, 0.01, 0.05]

print(param_transform(params, model))

args = [T, r_dry, ovf, c, model]

n_steps = 10
with warnings.catch_warnings():
    warnings.simplefilter('ignore', category=NumbaExperimentalFeatureWarning)
    param_chain, accept_chain, chi2_chain = MCMC(params, stepsize, args, datay, errory, n_steps)
#print(param_chain[:,-1])
p = param_transform(param_chain, model)
print(p[:,-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/n7/2_rw_xx11dd93cgp54t6tbn80000gn/T/ipykernel_47183/4078311394.py in <module>
#       4 from kappa_mcmc import param_transform, get_model, MCMC
#       5
# ----> 6 c = AerosolAlphaPineneDark(ovf)
#       7
#       8 # Ovad
#
# ~/anaconda3/envs/pysdm/lib/python3.9/site-packages/pystrict.py in wrapper(self, *args, **kwargs)
#      33     @functools.wraps(func)
#      34     def wrapper(self, *args, **kwargs):
# ---> 35         func(self, *args, **kwargs)
#      36         self._x_frozen = True
#      37     return wrapper
#
# ~/Research/PySDM-examples/PySDM_examples/Singer_Ward/aerosol.py in __init__(self, Forg, N)
#     123             {
#     124                 "f_org": 1 - self.f_soluble_volume(mode),
# --> 125                 "kappa": self.kappa(mode),
#     126                 "nu_org": self.nu_org(mode),
#     127                 "spectrum": spectra.Lognormal(
#
# ~/Research/PySDM/PySDM/initialisation/aerosol_composition/dry_aerosol.py in kappa(self, mass_fractions)
#      78             i: self.molar_masses[i] / self.densities[i] for i in self.compounds
#      79         }
# ---> 80         volume_fractions_of_just_soluble = self.volfrac_just_soluble(
#      81             volfrac, soluble=True
#      82         )
#
# ~/Research/PySDM/PySDM/initialisation/aerosol_composition/dry_aerosol.py in volfrac_just_soluble(self, volfrac, soluble)
#      66
#      67         _denom = sum(list(_masked.values()))
# ---> 68         if _denom == 0.0:
#      69             x = {k: 0.0 for k in self.compounds}
#      70         else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import mcmc_plots
reload(mcmc_plots)
from mcmc_plots import plot_param_chain, plot_corner, plot_ovf_kappa_fit, plot_keff

plot_param_chain(param_chain, args)
plot_corner(param_chain, args)
plot_ovf_kappa_fit(param_chain, args, d_ovf, datay, errory)
# plot_keff(param_chain, args, datay, errory)
